# %%
import sys

sys.path.append('../../')

import random
import numpy as np
import pylab as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, RandomSampler
from tqdm import tqdm

from sklearn import datasets
from dal_toolbox.models.deterministic.train import train_one_epoch_pimodel

# %%
X, y = datasets.make_moons(250, noise=.05, random_state=42)
X = (X - X.mean(0)) / X.std(0)
X = torch.from_numpy(X).float()
y = torch.from_numpy(y).long()

# %%
# Setup SSL 

class GaussianNoiseDataset(torch.utils.data.TensorDataset):
    def __init__(self, X, y, mean=0, std=1, noise=0.2):
        super(GaussianNoiseDataset, self).__init__(X, y)
        self.mean = mean
        self.std = std
        self.noise = noise
        assert noise >= 0 and noise <= 1, "noise is a probability and should be between 0 and 1"

    def __getitem__(self, idx):
        X, y = super().__getitem__(idx)
        X = X + torch.randn_like(X)*self.noise
        return X, y

random.seed(1)
indices_class0 = [i for i in range(len(y)) if y[i] == 0]
indices_class1 = [i for i in range(len(y)) if y[i] == 1]
labeled_indices = random.sample(indices_class0, k=4) + random.sample(indices_class1, k=4)
unlabeled_indices = [i for i in range(X.shape[0]) if i not in labeled_indices]

X_labeled, y_labeled = X[labeled_indices], y[labeled_indices]
X_unlabeled, y_unlabeled = X[unlabeled_indices], y[unlabeled_indices]

labeled_ds = torch.utils.data.TensorDataset(X_labeled, y_labeled)
# Using labeled and unlabeled data for unsupervised learning
unlabeled_ds_weak = GaussianNoiseDataset(X, y, noise=0.1)

plt.figure(figsize=(10,6), facecolor='silver')
plt.scatter(X_labeled[:, 0], X_labeled[:, 1], c=y_labeled, s=50, edgecolors='black', linewidths=3, label='labeled')
plt.scatter(X_unlabeled[:, 0], X_unlabeled[:, 1], c=y_unlabeled, s=10, alpha=0.5, label='unlabeled')
plt.legend()
plt.show()

# %%
class Net(nn.Module):
    def __init__(self, num_classes: int, dropout_rate: int = 0, feature_dim: int = 128):
        super().__init__()

        self.first = nn.Linear(2, feature_dim)
        self.first_dropout = nn.Dropout(dropout_rate)
        self.hidden = nn.Linear(feature_dim, feature_dim)
        self.hidden_dropout = nn.Dropout(dropout_rate)
        self.last = nn.Linear(feature_dim, num_classes)
        self.act = nn.ReLU()

    def forward(self, x, return_feature=False):
        x = self.act(self.first(x))
        x = self.first_dropout(x)
        x = self.act(self.hidden(x))
        x = self.hidden_dropout(x)
        out = self.last(x)
        if return_feature:
            return out, x
        return out

# %%
@torch.no_grad()
def plot_contour(model, X_l, y_l, X_u, y_u, ax=None):
    model.eval()
    model.cpu()
    origin = 'lower'
    if ax:
        plt.sca(ax)
    domain = 3
    xx, yy = torch.meshgrid(torch.linspace(-domain, domain, 51), torch.linspace(-domain, domain, 51), indexing='ij')
    zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)

    logits = model(zz)
    probas = logits.softmax(-1)
    zz = probas[:, 1].view(xx.shape)

    plt.scatter(X_l[:, 0], X_l[:, 1], c=y_l, s=50, edgecolors='red')
    plt.scatter(X_u[:, 0], X_u[:, 1], c=y_u, s=1)
    CS = plt.contourf(xx, yy, zz, alpha=.8, zorder=-1, levels=np.linspace(0, 1, 6), origin=origin)
    CS2 = plt.contour(CS, levels=[0.5], colors='black', origin=origin)
    cbar = plt.colorbar(CS)
    cbar.add_lines(CS2)

# %% [markdown]
# ## Pi-Model

# %%
torch.manual_seed(0)

n_epochs = 100 # number of epochs for training
n_iter = 10000 # number of total batches over the whole training
batch_size = 32 # batch_size of labeled samples per iteration
u_ratio = 1 # Ratio of unlabeled samples to labeled samples per batch
lambda_u = 30 # Ratio of unsupervised loss partition to supervised loss of total loss
unsup_warmup = 0.4 # Warm Up Factor for unsupervised loss during training

n_iter_per_epoch = n_iter // n_epochs
labeled_sampler = RandomSampler(labeled_ds, num_samples=n_iter_per_epoch*batch_size)
labeled_loader = DataLoader(labeled_ds, batch_size=batch_size, sampler=labeled_sampler)

unlabeled_sampler1 = RandomSampler(unlabeled_ds_weak, generator=torch.Generator().manual_seed(42), num_samples=u_ratio*n_iter_per_epoch*batch_size)
unlabeled_sampler2 = RandomSampler(unlabeled_ds_weak, generator=torch.Generator().manual_seed(42), num_samples=u_ratio*n_iter_per_epoch*batch_size)
unlabeled_loader1 = DataLoader(unlabeled_ds_weak, batch_size=batch_size*u_ratio, sampler=unlabeled_sampler1)
unlabeled_loader2 = DataLoader(unlabeled_ds_weak, batch_size=batch_size*u_ratio, sampler=unlabeled_sampler2)
pi_loaders = {
        "train_sup": labeled_loader,
        "train_unsup_weak_1": unlabeled_loader1,
        "train_unsup_weak_2": unlabeled_loader2
}

pi_optimizer_params = dict(lr=0.01, weight_decay=0.0001, momentum=.9,)
pi_model = Net(dropout_rate=0, num_classes=2)
pi_optimizer = torch.optim.SGD(pi_model.parameters(), **pi_optimizer_params)
criterion = torch.nn.CrossEntropyLoss()

history = []
for i in range(n_epochs):
    train_stats = train_one_epoch_pimodel(
        model=pi_model, dataloaders=pi_loaders, criterion=criterion, 
        optimizer=pi_optimizer, device='cuda', epoch=i, unsup_warmup=unsup_warmup, lambda_u=lambda_u,
        n_iter=n_iter)
    history.append(train_stats)

pi_model.eval()
plt.figure(figsize=(15, 5))
plt.subplot(121)
plot_contour(pi_model, X_labeled, y_labeled, X_unlabeled, y_unlabeled)
plt.subplot(122)
plt.plot([d['train_loss'] for d in history])
plt.show()
# Out:
# Epoch [0] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.6937 (0.6937) sup_loss: 0.6937 (0.6937) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 0.0000 (0.0000) acc1: 50.0000 (50.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [0] Total time: 0:00:00
# Epoch [1] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0188 (0.0188) sup_loss: 0.0087 (0.0087) unsup_loss: 0.0134 (0.0134) unsup_warmup_factor: 0.0250 (0.0250) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0003 max mem: 1
# Epoch [1] Total time: 0:00:00
# Epoch [2] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0125 (0.0125) sup_loss: 0.0044 (0.0044) unsup_loss: 0.0054 (0.0054) unsup_warmup_factor: 0.0500 (0.0500) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [2] Total time: 0:00:00
# Epoch [3] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0145 (0.0145) sup_loss: 0.0038 (0.0038) unsup_loss: 0.0048 (0.0048) unsup_warmup_factor: 0.0750 (0.0750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [3] Total time: 0:00:00
# Epoch [4] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0032 (0.0032) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0004 (0.0004) unsup_warmup_factor: 0.1000 (0.1000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [4] Total time: 0:00:00
# Epoch [5] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0301 (0.0301) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0075 (0.0075) unsup_warmup_factor: 0.1250 (0.1250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [5] Total time: 0:00:00
# Epoch [6] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0563 (0.0563) sup_loss: 0.0034 (0.0034) unsup_loss: 0.0117 (0.0117) unsup_warmup_factor: 0.1500 (0.1500) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [6] Total time: 0:00:00
# Epoch [7] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0526 (0.0526) sup_loss: 0.0018 (0.0018) unsup_loss: 0.0097 (0.0097) unsup_warmup_factor: 0.1750 (0.1750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [7] Total time: 0:00:00
# Epoch [8] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1012 (0.1012) sup_loss: 0.0015 (0.0015) unsup_loss: 0.0166 (0.0166) unsup_warmup_factor: 0.2000 (0.2000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [8] Total time: 0:00:00
# Epoch [9] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0636 (0.0636) sup_loss: 0.0074 (0.0074) unsup_loss: 0.0083 (0.0083) unsup_warmup_factor: 0.2250 (0.2250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [9] Total time: 0:00:00
# Epoch [10] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0669 (0.0669) sup_loss: 0.0039 (0.0039) unsup_loss: 0.0084 (0.0084) unsup_warmup_factor: 0.2500 (0.2500) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [10] Total time: 0:00:00
# Epoch [11] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0325 (0.0325) sup_loss: 0.0034 (0.0034) unsup_loss: 0.0035 (0.0035) unsup_warmup_factor: 0.2750 (0.2750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [11] Total time: 0:00:00
# Epoch [12] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0719 (0.0719) sup_loss: 0.0049 (0.0049) unsup_loss: 0.0074 (0.0074) unsup_warmup_factor: 0.3000 (0.3000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [12] Total time: 0:00:00
# Epoch [13] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0493 (0.0493) sup_loss: 0.0077 (0.0077) unsup_loss: 0.0043 (0.0043) unsup_warmup_factor: 0.3250 (0.3250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [13] Total time: 0:00:00
# Epoch [14] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0661 (0.0661) sup_loss: 0.0445 (0.0445) unsup_loss: 0.0021 (0.0021) unsup_warmup_factor: 0.3500 (0.3500) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [14] Total time: 0:00:00
# Epoch [15] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0866 (0.0866) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0075 (0.0075) unsup_warmup_factor: 0.3750 (0.3750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [15] Total time: 0:00:00
# Epoch [16] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0349 (0.0349) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0027 (0.0027) unsup_warmup_factor: 0.4000 (0.4000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [16] Total time: 0:00:00
# Epoch [17] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0319 (0.0319) sup_loss: 0.0102 (0.0102) unsup_loss: 0.0017 (0.0017) unsup_warmup_factor: 0.4250 (0.4250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [17] Total time: 0:00:00
# Epoch [18] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0665 (0.0665) sup_loss: 0.0040 (0.0040) unsup_loss: 0.0046 (0.0046) unsup_warmup_factor: 0.4500 (0.4500) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [18] Total time: 0:00:00
# Epoch [19] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0702 (0.0702) sup_loss: 0.0086 (0.0086) unsup_loss: 0.0043 (0.0043) unsup_warmup_factor: 0.4750 (0.4750) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [19] Total time: 0:00:00
# Epoch [20] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.2168 (0.2168) sup_loss: 0.0074 (0.0074) unsup_loss: 0.0140 (0.0140) unsup_warmup_factor: 0.5000 (0.5000) acc1: 100.0000 (100.0000) time: 0.0029 data: 0.0004 max mem: 1
# Epoch [20] Total time: 0:00:00
# Epoch [21] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0441 (0.0441) sup_loss: 0.0067 (0.0067) unsup_loss: 0.0024 (0.0024) unsup_warmup_factor: 0.5250 (0.5250) acc1: 100.0000 (100.0000) time: 0.0029 data: 0.0004 max mem: 1
# Epoch [21] Total time: 0:00:00
# Epoch [22] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1066 (0.1066) sup_loss: 0.0061 (0.0061) unsup_loss: 0.0061 (0.0061) unsup_warmup_factor: 0.5500 (0.5500) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0003 max mem: 1
# Epoch [22] Total time: 0:00:00
# Epoch [23] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1277 (0.1277) sup_loss: 0.0084 (0.0084) unsup_loss: 0.0069 (0.0069) unsup_warmup_factor: 0.5750 (0.5750) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0003 max mem: 1
# Epoch [23] Total time: 0:00:00
# Epoch [24] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1141 (0.1141) sup_loss: 0.0076 (0.0076) unsup_loss: 0.0059 (0.0059) unsup_warmup_factor: 0.6000 (0.6000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [24] Total time: 0:00:00
# Epoch [25] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1385 (0.1385) sup_loss: 0.0332 (0.0332) unsup_loss: 0.0056 (0.0056) unsup_warmup_factor: 0.6250 (0.6250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [25] Total time: 0:00:00
# Epoch [26] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0291 (0.0291) sup_loss: 0.0033 (0.0033) unsup_loss: 0.0013 (0.0013) unsup_warmup_factor: 0.6500 (0.6500) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [26] Total time: 0:00:00
# Epoch [27] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0176 (0.0176) sup_loss: 0.0107 (0.0107) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 0.6750 (0.6750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [27] Total time: 0:00:00
# Epoch [28] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.2464 (0.2464) sup_loss: 0.0047 (0.0047) unsup_loss: 0.0115 (0.0115) unsup_warmup_factor: 0.7000 (0.7000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [28] Total time: 0:00:00
# Epoch [29] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.2135 (0.2135) sup_loss: 0.0175 (0.0175) unsup_loss: 0.0090 (0.0090) unsup_warmup_factor: 0.7250 (0.7250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [29] Total time: 0:00:00
# Epoch [30] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0160 (0.0160) sup_loss: 0.0069 (0.0069) unsup_loss: 0.0004 (0.0004) unsup_warmup_factor: 0.7500 (0.7500) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0003 max mem: 1
# Epoch [30] Total time: 0:00:00
# Epoch [31] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0628 (0.0628) sup_loss: 0.0221 (0.0221) unsup_loss: 0.0018 (0.0018) unsup_warmup_factor: 0.7750 (0.7750) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0004 max mem: 1
# Epoch [31] Total time: 0:00:00
# Epoch [32] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1191 (0.1191) sup_loss: 0.0079 (0.0079) unsup_loss: 0.0046 (0.0046) unsup_warmup_factor: 0.8000 (0.8000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [32] Total time: 0:00:00
# Epoch [33] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0786 (0.0786) sup_loss: 0.0072 (0.0072) unsup_loss: 0.0029 (0.0029) unsup_warmup_factor: 0.8250 (0.8250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [33] Total time: 0:00:00
# Epoch [34] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.3157 (0.3157) sup_loss: 0.0104 (0.0104) unsup_loss: 0.0120 (0.0120) unsup_warmup_factor: 0.8500 (0.8500) acc1: 100.0000 (100.0000) time: 0.0029 data: 0.0003 max mem: 1
# Epoch [34] Total time: 0:00:00
# Epoch [35] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1754 (0.1754) sup_loss: 0.0070 (0.0070) unsup_loss: 0.0064 (0.0064) unsup_warmup_factor: 0.8750 (0.8750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [35] Total time: 0:00:00
# Epoch [36] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1735 (0.1735) sup_loss: 0.0037 (0.0037) unsup_loss: 0.0063 (0.0063) unsup_warmup_factor: 0.9000 (0.9000) acc1: 100.0000 (100.0000) time: 0.0029 data: 0.0003 max mem: 1
# Epoch [36] Total time: 0:00:00
# Epoch [37] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0368 (0.0368) sup_loss: 0.0040 (0.0040) unsup_loss: 0.0012 (0.0012) unsup_warmup_factor: 0.9250 (0.9250) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [37] Total time: 0:00:00
# Epoch [38] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0816 (0.0816) sup_loss: 0.0227 (0.0227) unsup_loss: 0.0021 (0.0021) unsup_warmup_factor: 0.9500 (0.9500) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [38] Total time: 0:00:00
# Epoch [39] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1318 (0.1318) sup_loss: 0.0179 (0.0179) unsup_loss: 0.0039 (0.0039) unsup_warmup_factor: 0.9750 (0.9750) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [39] Total time: 0:00:00
# Epoch [40] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0517 (0.0517) sup_loss: 0.0027 (0.0027) unsup_loss: 0.0016 (0.0016) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [40] Total time: 0:00:00
# Epoch [41] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0710 (0.0710) sup_loss: 0.0037 (0.0037) unsup_loss: 0.0022 (0.0022) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0039 data: 0.0004 max mem: 1
# Epoch [41] Total time: 0:00:00
# Epoch [42] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0170 (0.0170) sup_loss: 0.0028 (0.0028) unsup_loss: 0.0005 (0.0005) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0003 max mem: 1
# Epoch [42] Total time: 0:00:00
# Epoch [43] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0916 (0.0916) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0030 (0.0030) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [43] Total time: 0:00:00
# Epoch [44] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0927 (0.0927) sup_loss: 0.0056 (0.0056) unsup_loss: 0.0029 (0.0029) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [44] Total time: 0:00:00
# Epoch [45] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1168 (0.1168) sup_loss: 0.0028 (0.0028) unsup_loss: 0.0038 (0.0038) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [45] Total time: 0:00:00
# Epoch [46] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0715 (0.0715) sup_loss: 0.0034 (0.0034) unsup_loss: 0.0023 (0.0023) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [46] Total time: 0:00:00
# Epoch [47] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0524 (0.0524) sup_loss: 0.0016 (0.0016) unsup_loss: 0.0017 (0.0017) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [47] Total time: 0:00:00
# Epoch [48] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0116 (0.0116) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0026 data: 0.0002 max mem: 1
# Epoch [48] Total time: 0:00:00
# Epoch [49] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0133 (0.0133) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0004 (0.0004) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [49] Total time: 0:00:00
# Epoch [50] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0405 (0.0405) sup_loss: 0.0018 (0.0018) unsup_loss: 0.0013 (0.0013) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [50] Total time: 0:00:00
# Epoch [51] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0336 (0.0336) sup_loss: 0.0015 (0.0015) unsup_loss: 0.0011 (0.0011) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [51] Total time: 0:00:00
# Epoch [52] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0087 (0.0087) sup_loss: 0.0010 (0.0010) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [52] Total time: 0:00:00
# Epoch [53] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0155 (0.0155) sup_loss: 0.0016 (0.0016) unsup_loss: 0.0005 (0.0005) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [53] Total time: 0:00:00
# Epoch [54] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0593 (0.0593) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0019 (0.0019) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [54] Total time: 0:00:00
# Epoch [55] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0211 (0.0211) sup_loss: 0.0010 (0.0010) unsup_loss: 0.0007 (0.0007) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [55] Total time: 0:00:00
# Epoch [56] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0415 (0.0415) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0013 (0.0013) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [56] Total time: 0:00:00
# Epoch [57] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0200 (0.0200) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0006 (0.0006) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [57] Total time: 0:00:00
# Epoch [58] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0126 (0.0126) sup_loss: 0.0031 (0.0031) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [58] Total time: 0:00:00
# Epoch [59] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.1216 (0.1216) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0040 (0.0040) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0002 max mem: 1
# Epoch [59] Total time: 0:00:00
# Epoch [60] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0066 (0.0066) sup_loss: 0.0035 (0.0035) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [60] Total time: 0:00:00
# Epoch [61] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0082 (0.0082) sup_loss: 0.0007 (0.0007) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [61] Total time: 0:00:00
# Epoch [62] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0064 (0.0064) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [62] Total time: 0:00:00
# Epoch [63] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0024 (0.0024) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [63] Total time: 0:00:00
# Epoch [64] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0069 (0.0069) sup_loss: 0.0009 (0.0009) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0003 max mem: 1
# Epoch [64] Total time: 0:00:00
# Epoch [65] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0052 (0.0052) sup_loss: 0.0013 (0.0013) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [65] Total time: 0:00:00
# Epoch [66] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0012 (0.0012) sup_loss: 0.0004 (0.0004) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [66] Total time: 0:00:00
# Epoch [67] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0029 (0.0029) sup_loss: 0.0004 (0.0004) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [67] Total time: 0:00:00
# Epoch [68] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0042 (0.0042) sup_loss: 0.0002 (0.0002) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [68] Total time: 0:00:00
# Epoch [69] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0019 (0.0019) sup_loss: 0.0003 (0.0003) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [69] Total time: 0:00:00
# Epoch [70] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0037 (0.0037) sup_loss: 0.0003 (0.0003) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [70] Total time: 0:00:00
# Epoch [71] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0023 (0.0023) sup_loss: 0.0003 (0.0003) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [71] Total time: 0:00:00
# Epoch [72] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0031 (0.0031) sup_loss: 0.0004 (0.0004) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [72] Total time: 0:00:00
# Epoch [73] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0017 (0.0017) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [73] Total time: 0:00:00
# Epoch [74] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0003 (0.0003) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [74] Total time: 0:00:00
# Epoch [75] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0014 (0.0014) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [75] Total time: 0:00:00
# Epoch [76] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0010 (0.0010) sup_loss: 0.0003 (0.0003) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0003 max mem: 1
# Epoch [76] Total time: 0:00:00
# Epoch [77] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0002 (0.0002) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [77] Total time: 0:00:00
# Epoch [78] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0002 (0.0002) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [78] Total time: 0:00:00
# Epoch [79] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0006 (0.0006) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0026 data: 0.0002 max mem: 1
# Epoch [79] Total time: 0:00:00
# Epoch [80] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0014 (0.0014) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [80] Total time: 0:00:00
# Epoch [81] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0004 (0.0004) sup_loss: 0.0002 (0.0002) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [81] Total time: 0:00:00
# Epoch [82] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0151 (0.0151) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0005 (0.0005) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [82] Total time: 0:00:00
# Epoch [83] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0011 (0.0011) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [83] Total time: 0:00:00
# Epoch [84] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0008 (0.0008) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [84] Total time: 0:00:00
# Epoch [85] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0048 (0.0048) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [85] Total time: 0:00:00
# Epoch [86] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0017 (0.0017) sup_loss: 0.0002 (0.0002) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0026 data: 0.0002 max mem: 1
# Epoch [86] Total time: 0:00:00
# Epoch [87] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [87] Total time: 0:00:00
# Epoch [88] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0002 (0.0002) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [88] Total time: 0:00:00
# Epoch [89] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [89] Total time: 0:00:00
# Epoch [90] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0002 (0.0002) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [90] Total time: 0:00:00
# Epoch [91] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0008 (0.0008) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [91] Total time: 0:00:00
# Epoch [92] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0005 (0.0005) sup_loss: 0.0000 (0.0000) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [92] Total time: 0:00:00
# Epoch [93] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0002 (0.0002) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [93] Total time: 0:00:00
# Epoch [94] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0014 (0.0014) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [94] Total time: 0:00:00
# Epoch [95] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0006 (0.0006) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [95] Total time: 0:00:00
# Epoch [96] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0003 (0.0003) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [96] Total time: 0:00:00
# Epoch [97] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0008 (0.0008) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0028 data: 0.0002 max mem: 1
# Epoch [97] Total time: 0:00:00
# Epoch [98] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0007 (0.0007) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [98] Total time: 0:00:00
# Epoch [99] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0006 (0.0006) sup_loss: 0.0001 (0.0001) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0027 data: 0.0002 max mem: 1
# Epoch [99] Total time: 0:00:00
