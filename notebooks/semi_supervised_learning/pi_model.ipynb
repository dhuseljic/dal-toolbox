# %%
import sys

sys.path.append('../../')

import random
import numpy as np
import pylab as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, RandomSampler
from tqdm import tqdm

from sklearn import datasets
from dal_toolbox.models.deterministic.train import train_one_epoch_pimodel

# %%
X, y = datasets.make_moons(250, noise=.05, random_state=42)
X = (X - X.mean(0)) / X.std(0)
X = torch.from_numpy(X).float()
y = torch.from_numpy(y).long()

# %%
# Setup SSL 

class GaussianNoiseDataset(torch.utils.data.TensorDataset):
    def __init__(self, X, y, mean=0, std=1, noise=0.2):
        super(GaussianNoiseDataset, self).__init__(X, y)
        self.mean = mean
        self.std = std
        self.noise = noise
        assert noise >= 0 and noise <= 1, "noise is a probability and should be between 0 and 1"

    def __getitem__(self, idx):
        X, y = super().__getitem__(idx)
        X = X + torch.randn_like(X)*self.noise
        return X, y

random.seed(1)
indices_class0 = [i for i in range(len(y)) if y[i] == 0]
indices_class1 = [i for i in range(len(y)) if y[i] == 1]
labeled_indices = random.sample(indices_class0, k=4) + random.sample(indices_class1, k=4)
unlabeled_indices = [i for i in range(X.shape[0]) if i not in labeled_indices]

X_labeled, y_labeled = X[labeled_indices], y[labeled_indices]
X_unlabeled, y_unlabeled = X[unlabeled_indices], y[unlabeled_indices]

labeled_ds = torch.utils.data.TensorDataset(X_labeled, y_labeled)
# Using labeled and unlabeled data for unsupervised learning
unlabeled_ds_weak = GaussianNoiseDataset(X, y, noise=0.1)

plt.figure(figsize=(10,6), facecolor='silver')
plt.scatter(X_labeled[:, 0], X_labeled[:, 1], c=y_labeled, s=50, edgecolors='black', linewidths=3, label='labeled')
plt.scatter(X_unlabeled[:, 0], X_unlabeled[:, 1], c=y_unlabeled, s=10, alpha=0.5, label='unlabeled')
plt.legend()
plt.show()

# %%
class Net(nn.Module):
    def __init__(self, num_classes: int, dropout_rate: int = 0, feature_dim: int = 128):
        super().__init__()

        self.first = nn.Linear(2, feature_dim)
        self.first_dropout = nn.Dropout(dropout_rate)
        self.hidden = nn.Linear(feature_dim, feature_dim)
        self.hidden_dropout = nn.Dropout(dropout_rate)
        self.last = nn.Linear(feature_dim, num_classes)
        self.act = nn.ReLU()

    def forward(self, x, return_feature=False):
        x = self.act(self.first(x))
        x = self.first_dropout(x)
        x = self.act(self.hidden(x))
        x = self.hidden_dropout(x)
        out = self.last(x)
        if return_feature:
            return out, x
        return out

# %%
@torch.no_grad()
def plot_contour(model, X_l, y_l, X_u, y_u, ax=None):
    model.eval()
    model.cpu()
    origin = 'lower'
    if ax:
        plt.sca(ax)
    domain = 3
    xx, yy = torch.meshgrid(torch.linspace(-domain, domain, 51), torch.linspace(-domain, domain, 51), indexing='ij')
    zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)

    logits = model(zz)
    probas = logits.softmax(-1)
    zz = probas[:, 1].view(xx.shape)

    plt.scatter(X_l[:, 0], X_l[:, 1], c=y_l, s=50, edgecolors='red')
    plt.scatter(X_u[:, 0], X_u[:, 1], c=y_u, s=1)
    CS = plt.contourf(xx, yy, zz, alpha=.8, zorder=-1, levels=np.linspace(0, 1, 6), origin=origin)
    CS2 = plt.contour(CS, levels=[0.5], colors='black', origin=origin)
    cbar = plt.colorbar(CS)
    cbar.add_lines(CS2)

# %% [markdown]
# ## Pi-Model

# %%
torch.manual_seed(0)

n_epochs = 100 # number of epochs for training
n_iter = 10000 # number of total batches over the whole training
batch_size = 8 # batch_size of labeled samples per iteration
u_ratio = 10 # Ratio of unlabeled samples to labeled samples per batch
lambda_u = 15 # Ratio of unsupervised loss partition to supervised loss of total loss
unsup_warmup = 0.4 # Warm Up Factor for unsupervised loss during training

n_iter_per_epoch = n_iter // n_epochs
labeled_sampler = RandomSampler(labeled_ds, num_samples=n_iter_per_epoch*batch_size)
labeled_loader = DataLoader(labeled_ds, batch_size=batch_size, sampler=labeled_sampler)

unlabeled_sampler1 = RandomSampler(unlabeled_ds_weak, generator=torch.Generator().manual_seed(42), num_samples=u_ratio*n_iter_per_epoch*batch_size)
unlabeled_sampler2 = RandomSampler(unlabeled_ds_weak, generator=torch.Generator().manual_seed(42), num_samples=u_ratio*n_iter_per_epoch*batch_size)
unlabeled_loader1 = DataLoader(unlabeled_ds_weak, batch_size=batch_size*u_ratio, sampler=unlabeled_sampler1)
unlabeled_loader2 = DataLoader(unlabeled_ds_weak, batch_size=batch_size*u_ratio, sampler=unlabeled_sampler2)
pi_loaders = {
        "train_sup": labeled_loader,
        "train_unsup_weak_1": unlabeled_loader1,
        "train_unsup_weak_2": unlabeled_loader2
}

pi_optimizer_params = dict(lr=0.01, weight_decay=0.0001, momentum=.9,)
pi_model = Net(dropout_rate=0, num_classes=2)
pi_optimizer = torch.optim.SGD(pi_model.parameters(), **pi_optimizer_params)
criterion = torch.nn.CrossEntropyLoss()

history = []
for i in range(n_epochs):
    train_stats = train_one_epoch_pimodel(
        model=pi_model, dataloaders=pi_loaders, criterion=criterion, 
        optimizer=pi_optimizer, device='cuda', epoch=i, unsup_warmup=unsup_warmup, lambda_u=lambda_u,
        n_iter=n_iter)
    history.append(train_stats)

pi_model.eval()
plt.figure(figsize=(15, 5))
plt.subplot(121)
plot_contour(pi_model, X_labeled, y_labeled, X_unlabeled, y_unlabeled)
plt.subplot(122)
plt.plot([d['train_loss'] for d in history])
plt.show()
# Out:
# Epoch [0] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.6937 (0.6937) sup_loss: 0.6937 (0.6937) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 0.0000 (0.0000) acc1: 50.0000 (50.0000) time: 0.0051 data: 0.0002 max mem: 2
# Epoch [0] Total time: 0:00:00
# Epoch [1] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0105 (0.0105) sup_loss: 0.0085 (0.0085) unsup_loss: 0.0053 (0.0053) unsup_warmup_factor: 0.0250 (0.0250) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [1] Total time: 0:00:00
# Epoch [2] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0146 (0.0146) sup_loss: 0.0037 (0.0037) unsup_loss: 0.0146 (0.0146) unsup_warmup_factor: 0.0500 (0.0500) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [2] Total time: 0:00:00
# Epoch [3] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0297 (0.0297) sup_loss: 0.0024 (0.0024) unsup_loss: 0.0242 (0.0242) unsup_warmup_factor: 0.0750 (0.0750) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [3] Total time: 0:00:00
# Epoch [4] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0286 (0.0286) sup_loss: 0.0019 (0.0019) unsup_loss: 0.0178 (0.0178) unsup_warmup_factor: 0.1000 (0.1000) acc1: 100.0000 (100.0000) time: 0.0113 data: 0.0001 max mem: 2
# Epoch [4] Total time: 0:00:00
# Epoch [5] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0400 (0.0400) sup_loss: 0.0027 (0.0027) unsup_loss: 0.0199 (0.0199) unsup_warmup_factor: 0.1250 (0.1250) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [5] Total time: 0:00:00
# Epoch [6] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0525 (0.0525) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0226 (0.0226) unsup_warmup_factor: 0.1500 (0.1500) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [6] Total time: 0:00:00
# Epoch [7] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0246 (0.0246) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0085 (0.0085) unsup_warmup_factor: 0.1750 (0.1750) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [7] Total time: 0:00:00
# Epoch [8] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0158 (0.0158) sup_loss: 0.0016 (0.0016) unsup_loss: 0.0047 (0.0047) unsup_warmup_factor: 0.2000 (0.2000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [8] Total time: 0:00:00
# Epoch [9] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0156 (0.0156) sup_loss: 0.0016 (0.0016) unsup_loss: 0.0041 (0.0041) unsup_warmup_factor: 0.2250 (0.2250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [9] Total time: 0:00:00
# Epoch [10] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0732 (0.0732) sup_loss: 0.0018 (0.0018) unsup_loss: 0.0191 (0.0191) unsup_warmup_factor: 0.2500 (0.2500) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [10] Total time: 0:00:00
# Epoch [11] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0242 (0.0242) sup_loss: 0.0027 (0.0027) unsup_loss: 0.0052 (0.0052) unsup_warmup_factor: 0.2750 (0.2750) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [11] Total time: 0:00:00
# Epoch [12] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0315 (0.0315) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0065 (0.0065) unsup_warmup_factor: 0.3000 (0.3000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [12] Total time: 0:00:00
# Epoch [13] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0420 (0.0420) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0082 (0.0082) unsup_warmup_factor: 0.3250 (0.3250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [13] Total time: 0:00:00
# Epoch [14] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0762 (0.0762) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0141 (0.0141) unsup_warmup_factor: 0.3500 (0.3500) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [14] Total time: 0:00:00
# Epoch [15] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0492 (0.0492) sup_loss: 0.0091 (0.0091) unsup_loss: 0.0071 (0.0071) unsup_warmup_factor: 0.3750 (0.3750) acc1: 100.0000 (100.0000) time: 0.0063 data: 0.0001 max mem: 2
# Epoch [15] Total time: 0:00:00
# Epoch [16] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0661 (0.0661) sup_loss: 0.0056 (0.0056) unsup_loss: 0.0101 (0.0101) unsup_warmup_factor: 0.4000 (0.4000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [16] Total time: 0:00:00
# Epoch [17] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0211 (0.0211) sup_loss: 0.0043 (0.0043) unsup_loss: 0.0026 (0.0026) unsup_warmup_factor: 0.4250 (0.4250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [17] Total time: 0:00:00
# Epoch [18] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0202 (0.0202) sup_loss: 0.0046 (0.0046) unsup_loss: 0.0023 (0.0023) unsup_warmup_factor: 0.4500 (0.4500) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [18] Total time: 0:00:00
# Epoch [19] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0708 (0.0708) sup_loss: 0.0039 (0.0039) unsup_loss: 0.0094 (0.0094) unsup_warmup_factor: 0.4750 (0.4750) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [19] Total time: 0:00:00
# Epoch [20] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0426 (0.0426) sup_loss: 0.0038 (0.0038) unsup_loss: 0.0052 (0.0052) unsup_warmup_factor: 0.5000 (0.5000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [20] Total time: 0:00:00
# Epoch [21] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0670 (0.0670) sup_loss: 0.0104 (0.0104) unsup_loss: 0.0072 (0.0072) unsup_warmup_factor: 0.5250 (0.5250) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [21] Total time: 0:00:00
# Epoch [22] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0640 (0.0640) sup_loss: 0.0019 (0.0019) unsup_loss: 0.0075 (0.0075) unsup_warmup_factor: 0.5500 (0.5500) acc1: 100.0000 (100.0000) time: 0.0113 data: 0.0001 max mem: 2
# Epoch [22] Total time: 0:00:00
# Epoch [23] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0414 (0.0414) sup_loss: 0.0025 (0.0025) unsup_loss: 0.0045 (0.0045) unsup_warmup_factor: 0.5750 (0.5750) acc1: 100.0000 (100.0000) time: 0.0039 data: 0.0001 max mem: 2
# Epoch [23] Total time: 0:00:00
# Epoch [24] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0664 (0.0664) sup_loss: 0.0027 (0.0027) unsup_loss: 0.0071 (0.0071) unsup_warmup_factor: 0.6000 (0.6000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [24] Total time: 0:00:00
# Epoch [25] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0560 (0.0560) sup_loss: 0.0031 (0.0031) unsup_loss: 0.0056 (0.0056) unsup_warmup_factor: 0.6250 (0.6250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [25] Total time: 0:00:00
# Epoch [26] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0656 (0.0656) sup_loss: 0.0034 (0.0034) unsup_loss: 0.0064 (0.0064) unsup_warmup_factor: 0.6500 (0.6500) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [26] Total time: 0:00:00
# Epoch [27] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0774 (0.0774) sup_loss: 0.0146 (0.0146) unsup_loss: 0.0062 (0.0062) unsup_warmup_factor: 0.6750 (0.6750) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [27] Total time: 0:00:00
# Epoch [28] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0516 (0.0516) sup_loss: 0.0029 (0.0029) unsup_loss: 0.0046 (0.0046) unsup_warmup_factor: 0.7000 (0.7000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [28] Total time: 0:00:00
# Epoch [29] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.1041 (0.1041) sup_loss: 0.0024 (0.0024) unsup_loss: 0.0094 (0.0094) unsup_warmup_factor: 0.7250 (0.7250) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [29] Total time: 0:00:00
# Epoch [30] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0225 (0.0225) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0018 (0.0018) unsup_warmup_factor: 0.7500 (0.7500) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [30] Total time: 0:00:00
# Epoch [31] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0096 (0.0096) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0006 (0.0006) unsup_warmup_factor: 0.7750 (0.7750) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [31] Total time: 0:00:00
# Epoch [32] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0872 (0.0872) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0071 (0.0071) unsup_warmup_factor: 0.8000 (0.8000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [32] Total time: 0:00:00
# Epoch [33] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0212 (0.0212) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0015 (0.0015) unsup_warmup_factor: 0.8250 (0.8250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [33] Total time: 0:00:00
# Epoch [34] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0312 (0.0312) sup_loss: 0.0011 (0.0011) unsup_loss: 0.0024 (0.0024) unsup_warmup_factor: 0.8500 (0.8500) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [34] Total time: 0:00:00
# Epoch [35] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0723 (0.0723) sup_loss: 0.0016 (0.0016) unsup_loss: 0.0054 (0.0054) unsup_warmup_factor: 0.8750 (0.8750) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [35] Total time: 0:00:00
# Epoch [36] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0725 (0.0725) sup_loss: 0.0015 (0.0015) unsup_loss: 0.0053 (0.0053) unsup_warmup_factor: 0.9000 (0.9000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [36] Total time: 0:00:00
# Epoch [37] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0308 (0.0308) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0021 (0.0021) unsup_warmup_factor: 0.9250 (0.9250) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [37] Total time: 0:00:00
# Epoch [38] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0323 (0.0323) sup_loss: 0.0195 (0.0195) unsup_loss: 0.0009 (0.0009) unsup_warmup_factor: 0.9500 (0.9500) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [38] Total time: 0:00:00
# Epoch [39] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0550 (0.0550) sup_loss: 0.0345 (0.0345) unsup_loss: 0.0014 (0.0014) unsup_warmup_factor: 0.9750 (0.9750) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [39] Total time: 0:00:00
# Epoch [40] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0679 (0.0679) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0044 (0.0044) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [40] Total time: 0:00:00
# Epoch [41] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0494 (0.0494) sup_loss: 0.0041 (0.0041) unsup_loss: 0.0030 (0.0030) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0038 data: 0.0001 max mem: 2
# Epoch [41] Total time: 0:00:00
# Epoch [42] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0310 (0.0310) sup_loss: 0.0019 (0.0019) unsup_loss: 0.0019 (0.0019) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [42] Total time: 0:00:00
# Epoch [43] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0620 (0.0620) sup_loss: 0.0043 (0.0043) unsup_loss: 0.0039 (0.0039) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [43] Total time: 0:00:00
# Epoch [44] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0288 (0.0288) sup_loss: 0.0031 (0.0031) unsup_loss: 0.0017 (0.0017) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [44] Total time: 0:00:00
# Epoch [45] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0172 (0.0172) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0010 (0.0010) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [45] Total time: 0:00:00
# Epoch [46] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0274 (0.0274) sup_loss: 0.0191 (0.0191) unsup_loss: 0.0006 (0.0006) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [46] Total time: 0:00:00
# Epoch [47] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0369 (0.0369) sup_loss: 0.0014 (0.0014) unsup_loss: 0.0024 (0.0024) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0039 data: 0.0001 max mem: 2
# Epoch [47] Total time: 0:00:00
# Epoch [48] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0054 (0.0054) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0038 data: 0.0001 max mem: 2
# Epoch [48] Total time: 0:00:00
# Epoch [49] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0186 (0.0186) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0011 (0.0011) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0043 data: 0.0001 max mem: 2
# Epoch [49] Total time: 0:00:00
# Epoch [50] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0375 (0.0375) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0024 (0.0024) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [50] Total time: 0:00:00
# Epoch [51] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0180 (0.0180) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0011 (0.0011) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [51] Total time: 0:00:00
# Epoch [52] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0885 (0.0885) sup_loss: 0.0037 (0.0037) unsup_loss: 0.0057 (0.0057) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [52] Total time: 0:00:00
# Epoch [53] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0662 (0.0662) sup_loss: 0.0011 (0.0011) unsup_loss: 0.0043 (0.0043) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0040 data: 0.0001 max mem: 2
# Epoch [53] Total time: 0:00:00
# Epoch [54] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0794 (0.0794) sup_loss: 0.0043 (0.0043) unsup_loss: 0.0050 (0.0050) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [54] Total time: 0:00:00
# Epoch [55] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0729 (0.0729) sup_loss: 0.0024 (0.0024) unsup_loss: 0.0047 (0.0047) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [55] Total time: 0:00:00
# Epoch [56] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0556 (0.0556) sup_loss: 0.0029 (0.0029) unsup_loss: 0.0035 (0.0035) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [56] Total time: 0:00:00
# Epoch [57] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0196 (0.0196) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0012 (0.0012) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [57] Total time: 0:00:00
# Epoch [58] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0444 (0.0444) sup_loss: 0.0028 (0.0028) unsup_loss: 0.0028 (0.0028) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [58] Total time: 0:00:00
# Epoch [59] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0790 (0.0790) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0051 (0.0051) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [59] Total time: 0:00:00
# Epoch [60] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0263 (0.0263) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0016 (0.0016) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [60] Total time: 0:00:00
# Epoch [61] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0466 (0.0466) sup_loss: 0.0021 (0.0021) unsup_loss: 0.0030 (0.0030) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0111 data: 0.0001 max mem: 2
# Epoch [61] Total time: 0:00:00
# Epoch [62] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0164 (0.0164) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0009 (0.0009) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [62] Total time: 0:00:00
# Epoch [63] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0237 (0.0237) sup_loss: 0.0026 (0.0026) unsup_loss: 0.0014 (0.0014) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [63] Total time: 0:00:00
# Epoch [64] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0353 (0.0353) sup_loss: 0.0035 (0.0035) unsup_loss: 0.0021 (0.0021) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [64] Total time: 0:00:00
# Epoch [65] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0210 (0.0210) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0013 (0.0013) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [65] Total time: 0:00:00
# Epoch [66] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0359 (0.0359) sup_loss: 0.0028 (0.0028) unsup_loss: 0.0022 (0.0022) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [66] Total time: 0:00:00
# Epoch [67] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0301 (0.0301) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0019 (0.0019) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [67] Total time: 0:00:00
# Epoch [68] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0340 (0.0340) sup_loss: 0.0022 (0.0022) unsup_loss: 0.0021 (0.0021) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0111 data: 0.0001 max mem: 2
# Epoch [68] Total time: 0:00:00
# Epoch [69] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0234 (0.0234) sup_loss: 0.0029 (0.0029) unsup_loss: 0.0014 (0.0014) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [69] Total time: 0:00:00
# Epoch [70] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0198 (0.0198) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0012 (0.0012) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0111 data: 0.0001 max mem: 2
# Epoch [70] Total time: 0:00:00
# Epoch [71] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0158 (0.0158) sup_loss: 0.0014 (0.0014) unsup_loss: 0.0010 (0.0010) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0041 data: 0.0001 max mem: 2
# Epoch [71] Total time: 0:00:00
# Epoch [72] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0150 (0.0150) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0009 (0.0009) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0048 data: 0.0002 max mem: 2
# Epoch [72] Total time: 0:00:00
# Epoch [73] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0218 (0.0218) sup_loss: 0.0013 (0.0013) unsup_loss: 0.0014 (0.0014) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0039 data: 0.0001 max mem: 2
# Epoch [73] Total time: 0:00:00
# Epoch [74] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0310 (0.0310) sup_loss: 0.0020 (0.0020) unsup_loss: 0.0019 (0.0019) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0110 data: 0.0002 max mem: 2
# Epoch [74] Total time: 0:00:00
# Epoch [75] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0129 (0.0129) sup_loss: 0.0023 (0.0023) unsup_loss: 0.0007 (0.0007) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0111 data: 0.0001 max mem: 2
# Epoch [75] Total time: 0:00:00
# Epoch [76] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0142 (0.0142) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0009 (0.0009) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0039 data: 0.0001 max mem: 2
# Epoch [76] Total time: 0:00:00
# Epoch [77] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0063 (0.0063) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [77] Total time: 0:00:00
# Epoch [78] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0124 (0.0124) sup_loss: 0.0013 (0.0013) unsup_loss: 0.0007 (0.0007) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [78] Total time: 0:00:00
# Epoch [79] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0138 (0.0138) sup_loss: 0.0011 (0.0011) unsup_loss: 0.0008 (0.0008) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [79] Total time: 0:00:00
# Epoch [80] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0225 (0.0225) sup_loss: 0.0012 (0.0012) unsup_loss: 0.0014 (0.0014) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [80] Total time: 0:00:00
# Epoch [81] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0105 (0.0105) sup_loss: 0.0014 (0.0014) unsup_loss: 0.0006 (0.0006) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [81] Total time: 0:00:00
# Epoch [82] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0104 (0.0104) sup_loss: 0.0017 (0.0017) unsup_loss: 0.0006 (0.0006) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0117 data: 0.0001 max mem: 2
# Epoch [82] Total time: 0:00:00
# Epoch [83] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0023 (0.0023) sup_loss: 0.0013 (0.0013) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [83] Total time: 0:00:00
# Epoch [84] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0040 (0.0040) sup_loss: 0.0015 (0.0015) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [84] Total time: 0:00:00
# Epoch [85] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0209 (0.0209) sup_loss: 0.0013 (0.0013) unsup_loss: 0.0013 (0.0013) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [85] Total time: 0:00:00
# Epoch [86] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0091 (0.0091) sup_loss: 0.0009 (0.0009) unsup_loss: 0.0005 (0.0005) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [86] Total time: 0:00:00
# Epoch [87] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0026 (0.0026) sup_loss: 0.0009 (0.0009) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0111 data: 0.0002 max mem: 2
# Epoch [87] Total time: 0:00:00
# Epoch [88] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0020 (0.0020) sup_loss: 0.0010 (0.0010) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [88] Total time: 0:00:00
# Epoch [89] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0022 (0.0022) sup_loss: 0.0011 (0.0011) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0037 data: 0.0001 max mem: 2
# Epoch [89] Total time: 0:00:00
# Epoch [90] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0086 (0.0086) sup_loss: 0.0007 (0.0007) unsup_loss: 0.0005 (0.0005) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [90] Total time: 0:00:00
# Epoch [91] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0154 (0.0154) sup_loss: 0.0006 (0.0006) unsup_loss: 0.0010 (0.0010) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [91] Total time: 0:00:00
# Epoch [92] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0015 (0.0015) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [92] Total time: 0:00:00
# Epoch [93] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0023 (0.0023) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0113 data: 0.0001 max mem: 2
# Epoch [93] Total time: 0:00:00
# Epoch [94] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0020 (0.0020) sup_loss: 0.0004 (0.0004) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [94] Total time: 0:00:00
# Epoch [95] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0017 (0.0017) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0001 (0.0001) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [95] Total time: 0:00:00
# Epoch [96] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0009 (0.0009) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0035 data: 0.0001 max mem: 2
# Epoch [96] Total time: 0:00:00
# Epoch [97] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0009 (0.0009) sup_loss: 0.0004 (0.0004) unsup_loss: 0.0000 (0.0000) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0036 data: 0.0001 max mem: 2
# Epoch [97] Total time: 0:00:00
# Epoch [98] [  0/100] eta: 0:00:00 lr: 0.01 loss: 0.0052 (0.0052) sup_loss: 0.0006 (0.0006) unsup_loss: 0.0003 (0.0003) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0034 data: 0.0001 max mem: 2
# Epoch [98] Total time: 0:00:00
# Epoch [99] [  0/100] eta: 0:00:01 lr: 0.01 loss: 0.0035 (0.0035) sup_loss: 0.0005 (0.0005) unsup_loss: 0.0002 (0.0002) unsup_warmup_factor: 1.0000 (1.0000) acc1: 100.0000 (100.0000) time: 0.0112 data: 0.0001 max mem: 2
# Epoch [99] Total time: 0:00:00
