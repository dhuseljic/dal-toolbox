# %%
import mlflow
import numpy as np
import pylab as plt

client = mlflow.tracking.MlflowClient(tracking_uri='file:///home/dhuseljic/mlflow/ssal/ablation')
runs = client.search_runs( experiment_ids='164410855235082285')

# %%
runs[0]
# Out:
# <Run: data=<RunData: metrics={'ACE': 0.07141885161399841,
#  'AUPR': 0.5345525741577148,
#  'AUROC': 0.5576815605163574,
#  'accuracy': 0.262800008058548}, params={'dataset_name': 'cifar10',
#  'dataset_path': '/mnt/work/dhuseljic/datasets',
#  'dino_model_name': 'dinov2_vits14',
#  'mlflow_dir': '/mnt/work/dhuseljic/mlflow/ssal/ablation',
#  'model.kernel_scale': '1',
#  'model.mean_field_factor': '10',
#  'model.name': 'SNGP',
#  'model.num_epochs': '100',
#  'model.num_inducing': '1024',
#  'model.optimize_kernel_scale': 'True',
#  'model.predict_batch_size': '256',
#  'model.scale_random_features': 'True',
#  'model.train_batch_size': '32',
#  'num_train_samples': '10',
#  'ood_dataset_name': 'cifar100',
#  'optimizer.lr': '0.012338545030874467',
#  'optimizer.momentum': '0.9',
#  'optimizer.name': 'SGD',
#  'optimizer.weight_decay': '0.004886808093787658',
#  'output_dir': '/mnt/work/dhuseljic/results/ssal/test_dir',
#  'random_seed': '42'}, tags={'mlflow.runName': 'chill-owl-867',
#  'mlflow.source.name': 'ablation.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'dhuseljic'}>, info=<RunInfo: artifact_uri='file:///mnt/work/dhuseljic/mlflow/ssal/ablation/164410855235082285/1d5ce2da0da34813be88c994cbb96c16/artifacts', end_time=1705398326569, experiment_id='164410855235082285', lifecycle_stage='active', run_id='1d5ce2da0da34813be88c994cbb96c16', run_name='chill-owl-867', run_uuid='1d5ce2da0da34813be88c994cbb96c16', start_time=1705398294100, status='FINISHED', user_id='dhuseljic'>, inputs=<RunInputs: dataset_inputs=[]>>

# %% [markdown]
# ## Analysis of Optimizer Choice

# %% [markdown]
# ### SGD Optimizer

# %%
client = mlflow.tracking.MlflowClient(tracking_uri='file:///home/dhuseljic/mlflow/ssal/ablation')
query = "parameter.optimizer.name = 'SGD' and parameter.model.scale_random_features = 'False'"
runs = client.search_runs(experiment_ids='164410855235082285', filter_string=query)

lr_list =[]
weight_decay_list = []
accuracy_list = []
for run in runs:
    lr = float(run.data.params['optimizer.lr'])
    weight_decay = float(run.data.params['optimizer.weight_decay'])
    accuracy = float(run.data.metrics['accuracy'])
    lr_list.append(lr)
    weight_decay_list.append(weight_decay)
    accuracy_list.append(accuracy)

# %%
plt.scatter(lr_list, weight_decay_list, c=accuracy_list, cmap='coolwarm')
plt.colorbar()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
client = mlflow.tracking.MlflowClient(tracking_uri='file:///home/dhuseljic/mlflow/ssal/ablation')
query = "parameter.optimizer.name = 'SGD' and parameter.model.scale_random_features = 'True'"
runs = client.search_runs(experiment_ids='164410855235082285', filter_string=query)

lr_list =[]
weight_decay_list = []
accuracy_list = []
for run in runs:
    lr = float(run.data.params['optimizer.lr'])
    weight_decay = float(run.data.params['optimizer.weight_decay'])
    accuracy = float(run.data.metrics['accuracy'])
    lr_list.append(lr)
    weight_decay_list.append(weight_decay)
    accuracy_list.append(accuracy)

# %%
plt.scatter(lr_list, weight_decay_list, c=accuracy_list, cmap='coolwarm')
plt.colorbar()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Adam Optimizer

# %%
client = mlflow.tracking.MlflowClient(tracking_uri='file:///home/dhuseljic/mlflow/ssal/ablation')
query = "parameter.optimizer.name = 'Adam'"
runs = client.search_runs(experiment_ids='164410855235082285', filter_string=query)

lr_list =[]
weight_decay_list = []
accuracy_list = []
for run in runs:
    lr = float(run.data.params['optimizer.lr'])
    weight_decay = float(run.data.params['optimizer.weight_decay'])
    accuracy = float(run.data.metrics['accuracy'])
    lr_list.append(lr)
    weight_decay_list.append(weight_decay)
    accuracy_list.append(accuracy)
# Out:
# 200

# %%
plt.scatter(lr_list, weight_decay_list, c=accuracy_list, cmap='coolwarm')
plt.colorbar()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### AdamW

# %%
client = mlflow.tracking.MlflowClient(tracking_uri='file:///home/dhuseljic/mlflow/ssal/ablation')
query = "parameter.optimizer.name = 'AdamW'"
runs = client.search_runs(experiment_ids='164410855235082285', filter_string=query)

lr_list =[]
weight_decay_list = []
accuracy_list = []
for run in runs:
    lr = float(run.data.params['optimizer.lr'])
    weight_decay = float(run.data.params['optimizer.weight_decay'])
    accuracy = float(run.data.metrics['accuracy'])
    lr_list.append(lr)
    weight_decay_list.append(weight_decay)
    accuracy_list.append(accuracy)

# %%
plt.scatter(lr_list, weight_decay_list, c=accuracy_list, cmap='coolwarm')
plt.colorbar()
plt.xscale('log')
plt.yscale('log')
plt.show()
